# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./dataset_facebook.csv", sep = ";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.Type.unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
df_p = df.loc[df['Type'] == 'Photo']
df_p
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
df_v = df.loc[df['Type'] == 'Video']
df_v
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
df_l = df.loc[df['Type'] == 'Link']
df_l
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22             138414  Link         1          12             7         10
# 41             138895  Link         1          12             6          3
# 43             138353  Link         1          12             5          3
# 45             138353  Link         1          12             4          3
# 47             138353  Link         1          12             3          2
# 49             138353  Link         1          12             2          2
# 86             137177  Link         1          11             4          3
# 136            136393  Link         1          10             5         10
# 140            136013  Link         1          10             4          3
# 149            135713  Link         1          10             6         11
# 344            117764  Link         1           5             1          2
# ...

# %%
df_s = df.loc[df['Type'] == 'Status']
df_s
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
# df_sub = df.loc[(df['Type'] == 'Status') & (df['Total Interactions'] > 150)]

# %%
df_likes = df.sort_values(by = ['Page total likes'], ascending = False)
df_likes
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
print(df_p.shape, df_v.shape)
df_merge = pd.concat([df_p, df_v])
print(df_merge.shape)
# Out:
# (426, 19) (7, 19)
# (433, 19)

# %%
df_T = df.T
df_T.shape
# Out:
# (19, 500)

# %%
df_melt = pd.melt(df, id_vars = ['Type'], value_vars = ['comment'])
df_melt
# Out:
#        Type variable  value
# 0     Photo  comment      4
# 1    Status  comment      5
# 2     Photo  comment      0
# 3     Photo  comment     58
# 4     Photo  comment     19
# ..      ...      ...    ...
# 495   Photo  comment      5
# 496   Photo  comment      0
# 497   Photo  comment      4
# 498   Photo  comment      7
# 499   Photo  comment      0
#
# [500 rows x 3 columns]

# %%
df_pivot = df_melt.pivot(index = 'Type', columns = 'variable')['value']
df_pivot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-71c57a758a28> in <module>
# ----> 1 df_pivot = df_melt.pivot(index = 'Type', columns = 'variable')['value']
#       2 df_pivot
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    6877         from pandas.core.reshape.pivot import pivot
#    6878
# -> 6879         return pivot(self, index=index, columns=columns, values=values)
#    6880
#    6881     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     459         else:
#     460             indexed = data._constructor_sliced(data[values]._values, index=index)
# --> 461     return indexed.unstack(columns)
#     462
#     463
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
# ...
